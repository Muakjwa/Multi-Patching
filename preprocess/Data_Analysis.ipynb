# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import datetime

import plot_utils

# %%
train_label = pd.read_csv("../data/train_label.csv")
val_label = pd.read_csv("../data/val_label.csv")

# %%
plot_utils.plot_label_dist(train_label)

# %%
plot_utils.plot_label_dist(val_label)

# %%
test_activity = '../data/test_dataset/ch2024_test_m_activity.parquet.gzip'; test_activity = pd.read_parquet(test_activity)
test_ambience = '../data/test_dataset/ch2024_test_m_ambience.parquet.gzip'; test_ambience = pd.read_parquet(test_ambience)
test_heart_rate = '../data/test_dataset/ch2024_test_w_heart_rate.parquet.gzip'; test_heart_rate = pd.read_parquet(test_heart_rate)
test_w_light = '../data/test_dataset/ch2024_test_w_light.parquet.gzip'; test_w_light = pd.read_parquet(test_w_light)
test_light = '../data/test_dataset/ch2024_test_m_light.parquet.gzip'; test_light = pd.read_parquet(test_light)
test_pedo = '../data/test_dataset/ch2024_test_w_pedo.parquet.gzip'; test_pedo = pd.read_parquet(test_pedo)
test_usage_stats = '../data/test_dataset/ch2024_test_m_usage_stats.parquet.gzip'; test_usage_stats = pd.read_parquet(test_usage_stats)
test_gps = '../data/test_dataset/ch2024_test_m_gps.parquet.gzip'; test_gps = pd.read_parquet(test_gps)
test_acc_5 = '../data/test_dataset/ch2024_test__m_acc_part_5.parquet.gzip'; test_acc_5 = pd.read_parquet(test_acc_5)
test_acc_6 = '../data/test_dataset/ch2024_test__m_acc_part_6.parquet.gzip'; test_acc_6 = pd.read_parquet(test_acc_6)
test_acc_7 = '../data/test_dataset/ch2024_test__m_acc_part_7.parquet.gzip'; test_acc_7 = pd.read_parquet(test_acc_7)
test_acc_8 = '../data/test_dataset/ch2024_test__m_acc_part_8.parquet.gzip'; test_acc_8 = pd.read_parquet(test_acc_8)

# %%
val_activity = '../data/val_dataset/ch2024_val__m_activity.parquet.gzip'; val_activity = pd.read_parquet(val_activity)
val_ambience = '../data/val_dataset/ch2024_val__m_ambience.parquet.gzip'; val_ambience = pd.read_parquet(val_ambience)
val_heart_rate = '../data/val_dataset/ch2024_val__w_heart_rate.parquet.gzip'; val_heart_rate = pd.read_parquet(val_heart_rate)
val_w_light = '../data/val_dataset/ch2024_val__w_light.parquet.gzip'; val_w_light = pd.read_parquet(val_w_light)
val_light = '../data/val_dataset/ch2024_val__m_light.parquet.gzip'; val_light = pd.read_parquet(val_light)
val_pedo = '../data/val_dataset/ch2024_val__w_pedo.parquet.gzip'; val_pedo = pd.read_parquet(val_pedo)
val_usage_stats = '../data/val_dataset/ch2024_val__m_usage_stats.parquet.gzip'; val_usage_stats = pd.read_parquet(val_usage_stats)
val_gps = '../data/val_dataset/ch2024_val__m_gps.parquet.gzip'; val_gps = pd.read_parquet(val_gps)
val_acc_1 = '../data/val_dataset/ch2024_val__m_acc_part_1.parquet.gzip'; val_acc_1 = pd.read_parquet(val_acc_1)
val_acc_2 = '../data/val_dataset/ch2024_val__m_acc_part_2.parquet.gzip'; val_acc_2 = pd.read_parquet(val_acc_2)
val_acc_3 = '../data/val_dataset/ch2024_val__m_acc_part_3.parquet.gzip'; val_acc_3 = pd.read_parquet(val_acc_3)
val_acc_4 = '../data/val_dataset/ch2024_val__m_acc_part_4.parquet.gzip'; val_acc_4 = pd.read_parquet(val_acc_4)

# %%
plot_utils.plot_val_test(val_activity, subject_id=1, date="2023-08-20")

# %%
plot_utils.plot_val_test(val_heart_rate, subject_id=1, date="2023-08-20")

# %%
plot_utils.plot_val_test(val_w_light, subject_id=1, date="2023-08-20")

# %%
plot_utils.plot_val_test(val_light, subject_id=1, date="2023-08-20")

# %%
plot_utils.plot_val_test(val_pedo, subject_id=1, date="2023-08-20")

# %%
plot_utils.plot_val_test(val_acc_1, subject_id=1, date="2023-08-20")

# %%
plot_utils.plot_val_test(test_activity, subject_id=5, date="2023-11-05")

# %%
plot_utils.plot_val_test(test_heart_rate, subject_id=5, date="2023-11-05")

# %%
plot_utils.plot_val_test(test_w_light, subject_id=5, date="2023-11-05")

# %%
plot_utils.plot_val_test(test_light, subject_id=5, date="2023-11-05")

# %%
plot_utils.plot_val_test(test_pedo, subject_id=5, date="2023-11-05")

# %%
plot_utils.plot_val_test(test_acc_5, subject_id=5, date="2023-11-05")

# %%
val_gps[val_gps['subject_id'] == 4].plot.scatter(x="latitude", y="longitude", figsize=(8, 8), grid = True)
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
test_gps[test_gps['subject_id'] == 8].plot.scatter(x="latitude", y="longitude", figsize=(8, 8), grid = True)
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>
